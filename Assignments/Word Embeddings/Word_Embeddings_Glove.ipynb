# %%
from glove import Glove
import numpy as np

# %%
model = Glove(20)
# Out:
# Model initialised v3.5

# %%
Corpus = [
    'I see a little silhouette of a man', 
    'Dear mister fantasy, play us a tune',
    'a tune that will make us all happy'
]

# %%
history = model.fit_on_corpus(Corpus, iterations = 50000)
# Out:
# Shape of coocc = (20, 20)
# Forming the Co-Occurence Matrix : 100.00%
# Generated co-occurence matrix of shape (20, 20)
# Iteration 50000 : Cost = 0.9395717733961865

# %%
import matplotlib.pyplot as plt 
costs = history['cost']
iterations = [i for i in range(len(costs))]
plt.plot(iterations, costs)
plt.xlabel('iterations')
plt.ylabel('costs')
plt.title('training history')
plt.show()
