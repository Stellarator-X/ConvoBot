# %% [markdown]
# <a href="https://colab.research.google.com/github/Stellarator-X/ConvoBot/blob/servus/Programming%20Assignments/Speech%20Recognition/DeepSpeech.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !mkdir ds_utils

# %%
# !ls ds_utils
# Out:
# aesthetix.py  augmentation.py  data_manip.py

# %%
# !wget http://www.openslr.org/resources/31/dev-clean-2.tar.gz
# Out:
# --2020-06-15 20:27:20--  http://www.openslr.org/resources/31/dev-clean-2.tar.gz
# Resolving www.openslr.org (www.openslr.org)... 46.101.158.64
# Connecting to www.openslr.org (www.openslr.org)|46.101.158.64|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 126046265 (120M) [application/x-gzip]
# Saving to: ‘dev-clean-2.tar.gz’
#
# dev-clean-2.tar.gz  100%[===================>] 120.21M  8.80MB/s    in 16s
#
# 2020-06-15 20:27:37 (7.33 MB/s) - ‘dev-clean-2.tar.gz’ saved [126046265/126046265]

# %%
# !wget http://www.openslr.org/resources/31/train-clean-5.tar.gz
# Out:
# --2020-06-15 20:28:31--  http://www.openslr.org/resources/31/train-clean-5.tar.gz
# Resolving www.openslr.org (www.openslr.org)... 46.101.158.64
# Connecting to www.openslr.org (www.openslr.org)|46.101.158.64|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 332954390 (318M) [application/x-gzip]
# Saving to: ‘train-clean-5.tar.gz’
#
# train-clean-5.tar.g 100%[===================>] 317.53M  8.17MB/s    in 42s
#
# 2020-06-15 20:29:14 (7.48 MB/s) - ‘train-clean-5.tar.gz’ saved [332954390/332954390]

# %%
# !tar -xzf train-clean-5.tar.gz

# %%
# !mkdir ds_utils

# %%
# !python ds_utils/data_manip.py

# %%
# !ls ds_utils
# Out:
# aesthetix.py  augmentation.py  data_manip.py

# %%
from ds_utils.data_manip import *

# %%
import tensorflow as tf
import IPython

# %%
data = get_data(verbose=True)
# Out:
# 29 Files have been found.
# Reading files:[=============================](100.00%)
# (1519, 3)
# Loaded dataset with shape (1519, 2)

# %%
ids = data[:, 0]
labels = data[:, 1]
# Out:
# LibriSpeech/train-clean-5/226/122538/226-122538-0000.flac
# chapter fourteen in deryck's safe control the white cliffs of dover gradually became more solid and distinct until at length they rose from the sea a strong white wall
# LibriSpeech/train-clean-5/226/122538/226-122538-0001.flac
# strength and whiteness thought jane as she paced the steamer's deck and after a two years absence her heart went out to her native land then dover castle caught her eye so beautiful in the pearly light of that spring afternoon

# %%
print(labels[0])
IPython.display.Audio(ids[0])
# Out:
# chapter fourteen in deryck's safe control the white cliffs of dover gradually became more solid and distinct until at length they rose from the sea a strong white wall
#                 <audio controls="controls" >
#                     <source src="data:audio/flac;base64,..." type="audio/flac" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
datagen = SR_DataGenerator(ids, labels, augmentation_ratio=1)

# %%
a = datagen.__getitem__(0)

# %%
print(a[1].shape)
# Out:
# (32,)

# %%
# Char Map
import string
chars = list(string.ascii_lowercase)
# print(chars)
char_map = {ch:i for i, ch in enumerate(chars)}

char_map[' '] = 26
char_map['_'] = 27
char_map['.'] = 28

print(char_map)
# Out:
# {'a': 0, 'b': 1, 'c': 2, 'd': 3, 'e': 4, 'f': 5, 'g': 6, 'h': 7, 'i': 8, 'j': 9, 'k': 10, 'l': 11, 'm': 12, 'n': 13, 'o': 14, 'p': 15, 'q': 16, 'r': 17, 's': 18, 't': 19, 'u': 20, 'v': 21, 'w': 22, 'x': 23, 'y': 24, 'z': 25, ' ': 26, '_': 27, '.': 28}

# %%
from model import *

# %%
DSM = DSModel((1025, 2000, 1), char_map = char_map)

# %%
DSM.build()
DSM.compile()

# %%
DSM.model.summary()
# Out:
# Model: "DeepSpeech2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# Conv1 (Conv2D)               (None, 342, 667, 16)      160
# _________________________________________________________________
# Conv2 (Conv2D)               (None, 114, 223, 16)      2320
# _________________________________________________________________
# Conv3 (Conv2D)               (None, 38, 75, 16)        2320
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 1, 16)             0
# _________________________________________________________________
# RNN1 (Bidirectional)         (None, 1, 1600)           3926400
# _________________________________________________________________
# BatchNorm1 (SeqWiseBatchNorm (None, 1, 1600)           2
# _________________________________________________________________
# RNN2 (Bidirectional)         (None, 1, 1600)           11529600
# ...

# %%
DSM.model.fit(datagen)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-c08e0172934b> in <module>()
# ----> 1 DSM.model.fit(datagen)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#      64   def _method_wrapper(self, *args, **kwargs):
#      65     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# ---> 66       return method(self, *args, **kwargs)
#      67
#      68     # Running inside `run_distribute_coordinator` already.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
# ...
