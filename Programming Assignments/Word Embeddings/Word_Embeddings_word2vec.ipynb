# %%
from keras.models import Model
from keras.layers import Input, Dense, Reshape, Dot
from keras.layers.embeddings import Embedding
from keras.preprocessing.sequence import skipgrams
from keras.preprocessing import sequence
from keras.preprocessing.text import Tokenizer
from keras.preprocesssing.sequence import pad_sequences
import keras
import urllib
import collections
import os
import zipfile

import numpy as np
import tensorflow as tf

print(tf.__version__)
# Out:
# 2.2.0

# %%
def download(filename, url, expected_bytes):
    # Downloading the dataset
    if not os.path.exists(filename):
        filename, _ = urllib.request.urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified', filename)
    else:
        print(statinfo.st_size)
        raise Exception('Failed to verify ' + filename)
    return filename

def read_data(filename):
  
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data


def build_dataset(words, n_words):
    # Creating a dataset from input corpus
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(n_words - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count += 1
        data.append(index)
    count[0][1] = unk_count
    reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return data, count, dictionary, reversed_dictionary

# %%
def collect_data(vocabulary_size=10000):
    url = 'http://mattmahoney.net/dc/'
    filename = download('text8.zip', url, 31344016)
    vocabulary = read_data(filename)
    print(vocabulary[:7])
    data, count, dictionary, reverse_dictionary = build_dataset(vocabulary,
                                                                vocabulary_size)
    del vocabulary 
    return data, count, dictionary, reverse_dictionary

# %%
vocab_size = 10000
data, count, dictionary, reverse_dictionary = collect_data(vocabulary_size=vocab_size)
print(data[:7])

window_size = 3
vector_dim = 300
epochs = 200000

valid_size = 16     # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)

sampling_table = sequence.make_sampling_table(vocab_size)
couples, labels = skipgrams(data, vocab_size, window_size=window_size, sampling_table=sampling_table)
word_target, word_context = zip(*couples)
word_target = np.array(word_target, dtype="int32")
word_context = np.array(word_context, dtype="int32")

print(couples[:10], labels[:10])
# Out:
# Found and verified text8.zip
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse']
# [5234, 3081, 12, 6, 195, 2, 3134]
# [[1984, 1516], [3271, 540], [4535, 2459], [9624, 2], [30, 5436], [9064, 2], [3738, 1655], [2975, 7766], [9, 9], [5192, 9336]] [1, 1, 0, 1, 0, 1, 0, 0, 1, 0]

# %%
# Building the Model 

input_target = Input((1,))
input_context = Input((1,))

embedding = Embedding(vocab_size, vector_dim, input_length=1, name='embedding')
target = embedding(input_target)
target = Reshape((vector_dim, 1))(target)
context = embedding(input_context)
context = Reshape((vector_dim, 1))(context)
similarity = keras.layers.Dot(axes=1, normalize=True)([target, context]) # Cos similarity
dot_product = keras.layers.Dot(axes=1)([target, context])
dot_product = Reshape((1,))(dot_product)
output = Dense(1, activation='sigmoid')(dot_product)

model = Model(input=[input_target, input_context], output=output)
model.compile(loss='binary_crossentropy', optimizer='rmsprop')

model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_17 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# input_18 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 1, 300)       3000000     input_17[0][0]
#                                                                  input_18[0][0]
# __________________________________________________________________________________________________
# reshape_17 (Reshape)            (None, 300, 1)       0           embedding[0][0]
# __________________________________________________________________________________________________
# reshape_18 (Reshape)            (None, 300, 1)       0           embedding[1][0]
# __________________________________________________________________________________________________
# dot_4 (Dot)                     (None, 1, 1)         0           reshape_17[0][0]
#                                                                  reshape_18[0][0]
# __________________________________________________________________________________________________
# reshape_19 (Reshape)            (None, 1)            0           dot_4[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            2           reshape_19[0][0]
# ==================================================================================================
# Total params: 3,000,002
# Trainable params: 3,000,002
# Non-trainable params: 0
# __________________________________________________________________________________________________
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:20: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=[<tf.Tenso..., outputs=Tensor("de...)`

# %%
validation_model = Model(input=[input_target, input_context], output=similarity)


class SimilarityCallback:
    def run_sim(self):
        for i in range(valid_size):
            valid_word = reverse_dictionary[valid_examples[i]]
            top_k = 8  # number of nearest neighbors
            sim = self._get_sim(valid_examples[i])
            nearest = (-sim).argsort()[1:top_k + 1]
            log_str = 'Nearest to %s:' % valid_word
            for k in range(top_k):
                close_word = reverse_dictionary[nearest[k]]
                log_str = '%s %s,' % (log_str, close_word)
            print(log_str)

    @staticmethod
    def _get_sim(valid_word_idx):
        sim = np.zeros((vocab_size,))
        in_arr1 = np.zeros((1,))
        in_arr2 = np.zeros((1,))
        in_arr1[0,] = valid_word_idx
        for i in range(vocab_size):
            in_arr2[0,] = i
            out = validation_model.predict_on_batch([in_arr1, in_arr2])
            sim[i] = out
        return sim
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=[<tf.Tenso..., outputs=Tensor("do...)`

# %%
sim_cb = SimilarityCallback()

arr_1 = np.zeros((1,))
arr_2 = np.zeros((1,))
arr_3 = np.zeros((1,))
for cnt in range(epochs):
    idx = np.random.randint(0, len(labels)-1)
    arr_1[0,] = word_target[idx]
    arr_2[0,] = word_context[idx]
    arr_3[0,] = labels[idx]
    loss = model.train_on_batch([arr_1, arr_2], arr_3)
    if cnt % 100 == 0:
        print("Iteration {}, loss={}".format(cnt, loss))
    if cnt % 10000 == 0:
        sim_cb.run_sim()
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/indexed_slices.py:434: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Iteration 0, loss=0.6884893774986267
# Nearest to than: spellings, dj, catholic, norway, disneyland, colin, processed, masculine,
# Nearest to often: trick, methodist, sony, continue, cast, equation, borough, aesthetics,
# Nearest to nine: manchester, glucose, practicing, prussian, experiments, adobe, chromatic, held,
# Nearest to will: confederation, beckham, requirement, britain, committees, where, hypoglycemia, crushed,
# Nearest to used: exploits, manufacturers, reply, dave, celestial, cone, celebration, rhythmic,
# Nearest to when: contradiction, combination, import, playing, flower, proving, storage, accompanied,
# Nearest to while: peasant, hair, diary, subjective, mayo, aug, statistical, socialist,
# Nearest to d: like, kurdish, earthquakes, maintaining, habsburg, entering, aging, mapping,
# Nearest to called: plans, ballistic, flemish, levels, invasions, inuit, feminine, raise,
# Nearest to three: krak, singular, criminals, estonia, chapter, daleks, vs, serious,
# Nearest to see: parody, traditionally, domestic, potential, shelf, hybrid, therapy, advance,
# Nearest to his: resource, do, metallic, implemented, expertise, orientation, loading, difficulties,
# Iteration 6700, loss=0.6692253947257996
# Iteration 6800, loss=0.672728419303894
# Iteration 6900, loss=0.670813262462616
# Iteration 7000, loss=0.7130699157714844
# Iteration 7100, loss=0.7198432087898254
# Iteration 7200, loss=0.6743229627609253
# Iteration 7300, loss=0.7206624746322632
# Iteration 7400, loss=0.6815623641014099
# Iteration 7500, loss=0.6882377862930298
# Iteration 7600, loss=0.680520236492157
# Iteration 7700, loss=0.6601343750953674
# Iteration 7800, loss=0.7123728394508362
# Iteration 7900, loss=0.666908860206604
# Iteration 8000, loss=0.7063652873039246
# Iteration 8100, loss=0.716580867767334
# Iteration 8200, loss=0.6849556565284729
# Iteration 8300, loss=0.6693831086158752
# Iteration 8400, loss=0.6953344345092773
# Iteration 8500, loss=0.6912062168121338
# Iteration 8600, loss=0.7038263082504272
# Iteration 8700, loss=0.6716703772544861
# Iteration 8800, loss=0.6795928478240967
# Iteration 8900, loss=0.6870149374008179
# Iteration 9000, loss=0.7177659273147583
# Iteration 9100, loss=0.6810886263847351
# Iteration 9200, loss=0.6807698607444763
# Iteration 9300, loss=0.6827503442764282
# Iteration 9400, loss=0.7194036245346069
# Iteration 9500, loss=0.7280735969543457
# Iteration 9600, loss=0.7242347598075867
# Iteration 9700, loss=0.6609469056129456
# Iteration 9800, loss=0.6510894894599915
# Iteration 9900, loss=0.7307835817337036
# Iteration 10000, loss=0.7438174486160278
# Nearest to than: altar, spellings, disneyland, kg, connects, colin, dj, supplied,
# Nearest to often: trick, sony, continue, rainy, cast, royal, argentina, withdrawal,
# Nearest to nine: carnegie, evolve, caspian, manchester, roads, width, supporting, carlos,
# Nearest to will: requirement, beckham, rightarrow, ulster, precedent, immense, confederation, committees,
# Nearest to used: afl, philosophical, cone, reply, manufacturers, boiling, exploits, dave,
# Nearest to when: combination, contradiction, your, bang, flower, georg, accompanied, democrat,
# Nearest to while: mayo, diary, peasant, comedian, statistical, aug, subjective, hair,
# Nearest to d: earthquakes, like, seal, kurdish, maintaining, implementation, grains, entering,
# Nearest to called: levels, ballistic, plans, invasions, neural, alkanes, spells, severely,
# Nearest to three: cry, consumed, cites, publicity, wimbledon, games, singular, flaws,
# Nearest to see: bridge, potential, domestic, shelf, parody, su, hybrid, peel,
# Nearest to his: metallic, louis, lineup, orientation, poles, mtv, eddie, difficulties,
# Nearest to be: impact, cyberpunk, aesthetics, wholly, ranging, breast, drops, enters,
# Nearest to only: painting, buchanan, alexandria, cosmological, algeria, eliminated, weights, makers,
# Nearest to so: jimmy, along, psychiatric, founders, re, entry, battlefield, euclid,
# Nearest to of: independent, inequality, repeated, negative, scripts, surprised, ti, saddam,
# Iteration 10100, loss=0.6806511282920837
# Iteration 10200, loss=0.7196967601776123
# Iteration 10300, loss=0.7196394205093384
# Iteration 10400, loss=0.6847641468048096
# Iteration 10500, loss=0.678921639919281
# Iteration 10600, loss=0.6619778871536255
# Iteration 10700, loss=0.6498103737831116
# Iteration 10800, loss=0.7131991386413574
# Iteration 10900, loss=0.6830936670303345
# Iteration 18300, loss=0.7128905057907104
# Iteration 18400, loss=0.6662926077842712
# Iteration 18500, loss=0.7157158255577087
# Iteration 18600, loss=0.7110451459884644
# Iteration 18700, loss=0.7054752707481384
# Iteration 18800, loss=0.6963350772857666
# Iteration 18900, loss=0.7013422250747681
# Iteration 19000, loss=0.6883140802383423
# Iteration 19100, loss=0.6903953552246094
# Iteration 19200, loss=0.6872394680976868
# Iteration 19300, loss=0.706993818283081
# Iteration 19400, loss=0.7115533947944641
# Iteration 19500, loss=0.6689035296440125
# Iteration 19600, loss=0.6924155950546265
# Iteration 19700, loss=0.6942416429519653
# Iteration 19800, loss=0.6896302103996277
# Iteration 19900, loss=0.694672703742981
# Iteration 20000, loss=0.6780403852462769
# Nearest to than: altar, connects, disneyland, television, investors, colin, spellings, dated,
# Nearest to often: sony, rainy, trick, cast, emphasized, circuits, continue, uniquely,
# Nearest to nine: manchester, struck, stick, abraham, prussia, follows, mythology, caspian,
# Nearest to will: hypoglycemia, judaism, cables, confederation, neighboring, rightarrow, beckham, warm,
# Nearest to used: rugby, philosophical, wavelength, test, afl, exploits, boiling, capacitor,
# Nearest to when: combination, walk, screenplay, your, bang, aromatic, debt, letterman,
# Nearest to while: peasant, mayo, aug, diary, comedian, damaging, subjective, reasonably,
# Nearest to d: earthquakes, argues, creates, implementation, interestingly, profits, almost, extensive,
# Nearest to called: ballistic, would, spells, levels, plans, substrate, tested, severely,
# Nearest to three: cry, territorial, cites, fifteen, troubled, karl, venture, singular,
# Nearest to see: bridge, potential, parody, domestic, shelf, peel, comment, su,
# Nearest to his: controversies, determined, metallic, orientation, lynx, subcontinent, lose, poet,
# Nearest to be: impact, cyberpunk, dance, severely, arena, attendance, dartmouth, noir,
# Nearest to only: painting, alexandria, moved, eliminated, happens, buchanan, cosmological, weights,
# Nearest to so: jimmy, along, entry, richard, re, founders, people, capacity,
# Nearest to of: goddess, inequality, repeated, negative, hanover, institute, withdraw, loud,
# Iteration 20100, loss=0.6659015417098999
# Iteration 20200, loss=0.6932355761528015
# Iteration 20300, loss=0.7195001840591431
# Iteration 20400, loss=0.7204998731613159
# Iteration 20500, loss=0.6636048555374146
# Iteration 20600, loss=0.7075123190879822
# Iteration 20700, loss=0.732600748538971
# Iteration 20800, loss=0.6571598649024963
# Iteration 20900, loss=0.64507657289505
# Iteration 21000, loss=0.7338945269584656
# Iteration 21100, loss=0.6853272914886475
# Iteration 21200, loss=0.7177448272705078
# Iteration 21300, loss=0.7001248598098755
# Iteration 21400, loss=0.6848178505897522
# Iteration 21500, loss=0.7123218774795532
# Iteration 21600, loss=0.658206582069397
# Iteration 21700, loss=0.6549596190452576
# Iteration 21800, loss=0.6941362619400024
# Iteration 21900, loss=0.709749162197113
# Iteration 22000, loss=0.6979509592056274
# Iteration 22100, loss=0.7024871706962585
# Iteration 22200, loss=0.6926932334899902
# Iteration 22300, loss=0.6769877672195435
# Iteration 22400, loss=0.7044845223426819
# Iteration 22500, loss=0.6921387910842896
# Iteration 22600, loss=0.6907511949539185
# Nearest to than: altar, connects, disneyland, feared, enables, ip, stating, catholic,
# Nearest to often: devoted, rainy, sony, circuits, continue, rob, rifle, lessons,
# Nearest to nine: manchester, mishnah, struck, opera, abraham, prussia, affairs, odd,
# Nearest to will: wireless, judaism, hypoglycemia, flowing, confederation, correspond, rightarrow, cables,
# Nearest to used: rugby, philosophical, wavelength, test, exploits, dave, reds, saxons,
# Nearest to when: august, combination, your, fixed, scholarly, bang, screenplay, flower,
# Nearest to while: mayo, aug, comedian, core, diary, subjective, reasonably, peasant,
# Nearest to d: earthquakes, profits, implementation, creates, argues, manchester, wouldn, link,
# Nearest to called: would, invasions, outcome, levels, ballistic, tone, variable, raise,
# Nearest to three: fao, venture, cry, cites, genera, implies, prosecution, troubled,
# Nearest to see: bridge, domestic, su, parody, shelf, potential, peel, deep,
# Nearest to his: controversies, metallic, determined, resist, lynx, pp, poet, formats,
# Nearest to be: impact, distillation, attendance, cyberpunk, plague, questionable, dance, arena,
# Nearest to only: painting, cosmological, encryption, buchanan, alexandria, tolkien, eliminated, prisoner,
# Nearest to so: jimmy, along, disco, re, entry, founders, null, remains,
# Nearest to of: repeated, packet, grammar, denis, putting, instability, institute, undergraduate,
# Iteration 30100, loss=0.7009506225585938
# Iteration 30200, loss=0.7045381665229797
# Iteration 30300, loss=0.7030702829360962
# Iteration 30400, loss=0.7110365629196167
# Iteration 30500, loss=0.6785314679145813
# Iteration 30600, loss=0.9213520884513855
# Iteration 30700, loss=0.6992707252502441
# Iteration 30800, loss=0.7051236033439636
# Iteration 30900, loss=0.7200621366500854
# Iteration 31000, loss=0.6945063471794128
# Iteration 31100, loss=0.7080819606781006
# Iteration 31200, loss=0.7231103777885437
# Iteration 31300, loss=0.7062544226646423
# Iteration 31400, loss=0.7029840350151062
# Iteration 31500, loss=0.6666824221611023
# Iteration 31600, loss=0.6821697354316711
# Iteration 31700, loss=0.689440906047821
# Iteration 31800, loss=0.6608796715736389
# Iteration 31900, loss=0.709048330783844
# Iteration 32000, loss=0.6776568293571472
# Iteration 32100, loss=0.6905287504196167
# Iteration 32200, loss=0.6532778143882751
# Iteration 32300, loss=0.6926885843276978
# Iteration 32400, loss=0.5808848142623901
# Iteration 32500, loss=0.7056154012680054
# Iteration 32600, loss=0.6994208097457886
# Iteration 32700, loss=0.9435452222824097
# Iteration 32800, loss=0.6975434422492981
# Iteration 32900, loss=0.7037256360054016
# Iteration 33000, loss=0.6968551278114319
# Iteration 33100, loss=0.6731889843940735
# Iteration 33200, loss=0.7228958606719971
# Iteration 33300, loss=0.7255975008010864
# Iteration 33400, loss=0.7117120027542114
# Iteration 33500, loss=0.7413712739944458
# Iteration 33600, loss=0.6648126244544983
# Iteration 33700, loss=0.7498305439949036
# Iteration 33800, loss=0.7150937914848328
# Iteration 33900, loss=0.7144785523414612
# Iteration 34000, loss=0.6717711687088013
# Iteration 34100, loss=0.6520056128501892
# Iteration 34200, loss=0.7368524074554443
# Iteration 34300, loss=0.7414494156837463
# Iteration 46100, loss=0.7152864336967468
# Iteration 46200, loss=0.7254887223243713
# Iteration 46300, loss=0.6771613359451294
# Iteration 46400, loss=0.6822649240493774
# Iteration 46500, loss=0.6985099911689758
# Iteration 46600, loss=0.7102718949317932
# Iteration 46700, loss=0.6838437914848328
# Iteration 46800, loss=0.6761509776115417
# Iteration 46900, loss=0.679413378238678
# Iteration 47000, loss=0.704902708530426
# Iteration 47100, loss=0.6918431520462036
# Iteration 47200, loss=0.5809112191200256
# Iteration 47300, loss=0.6877478957176208
# Iteration 47400, loss=0.6992050409317017
# Iteration 47500, loss=0.7332635521888733
# Iteration 47600, loss=0.6752079725265503
# Iteration 47700, loss=0.688156247138977
# Iteration 47800, loss=0.6778318881988525
# Iteration 47900, loss=0.6956107020378113
# Iteration 48000, loss=0.696047306060791
# Iteration 48100, loss=0.6995129585266113
# Iteration 48200, loss=0.6989678144454956
# Iteration 48300, loss=0.636752188205719
# Iteration 48400, loss=0.6890257000923157
# Iteration 48500, loss=0.7019494771957397
# Iteration 48600, loss=0.6833113431930542
# Iteration 48700, loss=0.6757899522781372
# Iteration 48800, loss=0.6400130391120911
# Iteration 48900, loss=0.661749005317688
# Iteration 49000, loss=0.6772533655166626
# Iteration 49100, loss=0.6700465083122253
# Iteration 49200, loss=0.7109553217887878
# Iteration 49300, loss=0.7517266273498535
# Iteration 49400, loss=0.7033194899559021
# Iteration 49500, loss=0.6556179523468018
# Iteration 49600, loss=0.7008187770843506
# Iteration 49700, loss=0.6923342347145081
# Iteration 49800, loss=0.6851202249526978
# Iteration 49900, loss=0.7272170186042786
# Iteration 50000, loss=0.6699562072753906
# Nearest to than: connects, disneyland, enables, reich, rendering, facility, four, vast,
# Nearest to often: bordered, devoted, lead, september, inner, continue, strategies, promoting,
# Nearest to nine: nirvana, citizens, races, guitar, styled, manchester, odd, cult,
# Nearest to will: liturgy, confederation, wireless, immense, with, place, encoding, advance,
# Nearest to used: philosophical, wavelength, saxons, modernism, counterpoint, exploits, proximity, test,
# Nearest to when: august, combination, leeds, scholarly, fixed, flower, nevertheless, hitchcock,
# Nearest to while: arrive, socialist, hughes, mayo, core, reasonably, stored, diary,
# Nearest to d: fewer, chamber, earthquakes, almost, treatise, profits, hood, conjunction,
# Nearest to called: invasions, ballistic, impression, licensed, substrate, committed, forms, eugene,
# Nearest to three: developments, fao, wimbledon, cites, extensions, something, later, troubled,
# Nearest to see: bridge, sight, mail, choice, parody, innings, perform, prohibition,
# Nearest to his: controversies, spheres, proprietary, crosby, easier, hole, determined, ipcc,
# Nearest to be: impact, similarity, ranging, enters, parks, distillation, cruise, moves,
# Nearest to only: encryption, retains, cia, painting, joshua, artistic, franco, blades,
# Nearest to so: instantly, massachusetts, assume, jimmy, increases, disco, null, heaven,
# Nearest to of: the, ori, ace, institute, grammar, supposedly, a, withdraw,
# Iteration 50100, loss=0.7172077298164368
# Iteration 50200, loss=0.6117959022521973
# Iteration 50300, loss=0.7493501901626587
# Iteration 50400, loss=0.6930936574935913
# Iteration 57800, loss=0.6919224858283997
# Iteration 57900, loss=0.704774796962738
# Iteration 58000, loss=0.685867965221405
# Iteration 58100, loss=0.6935432553291321
# Iteration 58200, loss=0.6843295693397522
# Iteration 58300, loss=0.7215393781661987
# Iteration 58400, loss=0.6957049369812012
# Iteration 58500, loss=0.7147975564002991
# Iteration 58600, loss=0.6762531399726868
# Iteration 58700, loss=0.6046663522720337
# Iteration 58800, loss=0.819034218788147
# Iteration 58900, loss=0.6663997769355774
# Iteration 59000, loss=0.7054312229156494
# Iteration 59100, loss=0.6713524460792542
# Iteration 59200, loss=0.6596248745918274
# Iteration 59300, loss=0.6688399910926819
# Iteration 59400, loss=0.6663922667503357
# Iteration 59500, loss=0.6816873550415039
# Iteration 59600, loss=0.6847230792045593
# Iteration 59700, loss=0.6954494714736938
# Iteration 59800, loss=0.7140509486198425
# Iteration 59900, loss=0.64365553855896
# Iteration 60000, loss=0.7427806258201599
# Nearest to than: san, single, enables, connects, disneyland, variety, vast, facility,
# Nearest to often: bordered, devoted, strategies, sensitivity, september, assembly, inner, sony,
# Nearest to nine: highlands, citizens, nirvana, abraham, races, itu, rivers, leather,
# Nearest to will: immense, wireless, confederation, with, advance, remains, liturgy, addressed,
# Nearest to used: saxons, philosophical, counterpoint, exploits, radical, then, wavelength, proximity,
# Nearest to when: august, combination, notorious, fixed, unofficial, leeds, styled, aromatic,
# Nearest to while: arrive, socialist, hughes, resumed, ballot, mayo, orchestral, acceptance,
# Nearest to d: chamber, fewer, demonstration, earthquakes, conjunction, hood, almost, argues,
# Nearest to called: impression, invasions, ballistic, licensed, substrate, embraced, quartet, forms,
# Nearest to three: developments, later, cites, fao, something, fulfilled, coca, wimbledon,
# Nearest to see: bridge, sight, domestic, mail, parody, therapy, innings, ceremonies,
# Nearest to his: controversies, spheres, conversely, proprietary, settings, crosby, challenges, lose,
# Nearest to be: impact, plague, strongly, damages, moves, highest, ranging, dance,
# Nearest to only: cia, encryption, retains, painting, artistic, bare, cosmological, alexandria,
# Nearest to so: instantly, massachusetts, jimmy, assume, entry, increases, noun, heaven,
# Nearest to of: the, in, to, institute, two, ace, ori, packet,
# Iteration 60100, loss=0.7387264966964722
# Iteration 60200, loss=0.5960187911987305
# Iteration 60300, loss=0.5292283296585083
# Iteration 60400, loss=0.5620426535606384
# Iteration 60500, loss=0.6590878367424011
# Iteration 60600, loss=0.6364050507545471
# Iteration 60700, loss=0.6380204558372498
# Iteration 60800, loss=0.7209426760673523
# Iteration 60900, loss=0.6975154876708984
# Iteration 61000, loss=0.6811538338661194
# Iteration 61100, loss=0.7046527862548828
# Iteration 61200, loss=0.7151554226875305
# Iteration 61300, loss=0.716069757938385
# Iteration 61400, loss=0.5824508666992188
# Iteration 61500, loss=0.7405129671096802
# Iteration 61600, loss=0.6917509436607361
# Iteration 61700, loss=0.6562635898590088
# Iteration 61800, loss=0.6791508793830872
# Iteration 61900, loss=0.6761530637741089
# Iteration 62000, loss=0.7419705390930176
# Iteration 62100, loss=0.679426908493042
# Iteration 69500, loss=0.7042362689971924
# Iteration 69600, loss=0.3255562484264374
# Iteration 69700, loss=0.713201105594635
# Iteration 69800, loss=0.7445771098136902
# Iteration 69900, loss=0.6092390418052673
# Iteration 70000, loss=0.7179657220840454
# Nearest to than: san, enables, typical, single, ceased, norway, disneyland, had,
# Nearest to often: devoted, bordered, strategies, lead, september, rainy, sony, continue,
# Nearest to nine: highlands, citizens, abraham, change, criticized, nirvana, photographic, rivers,
# Nearest to will: confederation, immense, encoding, with, wireless, remains, course, addressed,
# Nearest to used: saxons, philosophical, wavelength, radical, earth, counterpoint, documentary, exploits,
# Nearest to when: august, combination, scholarly, notorious, styled, leeds, anti, fixed,
# Nearest to while: arrive, socialist, hughes, orchestral, gang, peasant, resumed, foreigners,
# Nearest to d: chamber, fewer, demonstration, conjunction, resignation, argues, earthquakes, start,
# Nearest to called: impression, invasions, substrate, ballistic, licensed, estimated, tribute, akin,
# Nearest to three: developments, internal, later, cites, continued, coca, radioactive, something,
# Nearest to see: bridge, sight, philosophy, murders, therapy, innings, detect, choice,
# Nearest to his: controversies, conversely, crosby, month, easier, dramatic, proprietary, agreement,
# Nearest to be: giuseppe, so, descended, walking, impact, damages, missionaries, action,
# Nearest to only: businesses, cia, retains, mosque, cause, bare, painting, aim,
# Nearest to so: instantly, jimmy, massachusetts, aclu, be, entry, assume, noun,
# Nearest to of: the, to, in, a, two, packet, schumacher, from,
# Iteration 70100, loss=0.7076382040977478
# Iteration 70200, loss=0.664801299571991
# Iteration 70300, loss=0.7498321533203125
# Iteration 70400, loss=0.6585655212402344
# Iteration 70500, loss=0.305184930562973
# Iteration 70600, loss=0.678548276424408
# Iteration 70700, loss=0.5741784572601318
# Iteration 70800, loss=0.7039172649383545
# Iteration 70900, loss=0.7016672492027283
# Iteration 71000, loss=0.7351582050323486
# Iteration 71100, loss=0.5897207260131836
# Iteration 71200, loss=0.6895520091056824
# Iteration 71300, loss=0.6803337931632996
# Iteration 71400, loss=0.7377015948295593
# Iteration 71500, loss=0.6398574709892273
# Iteration 71600, loss=0.6798796653747559
# Iteration 71700, loss=0.6755262017250061
# Iteration 71800, loss=0.7079160213470459
# Iteration 71900, loss=0.7593815326690674
# Iteration 72000, loss=0.7231800556182861
# Iteration 72100, loss=0.6586852669715881
# Iteration 72200, loss=0.7525566816329956
# Iteration 72300, loss=0.7032229900360107
# Iteration 72400, loss=0.673918604850769
# Iteration 72500, loss=0.6920723915100098
# Iteration 72600, loss=0.6325225830078125
# Iteration 72700, loss=0.6634145975112915
# Iteration 72800, loss=0.6707939505577087
# Iteration 72900, loss=0.7004702687263489
# Iteration 73000, loss=0.6704182028770447
# Iteration 73100, loss=0.6808172464370728
# Iteration 73200, loss=0.6421185731887817
# Iteration 73300, loss=0.7353675365447998
# Iteration 73400, loss=0.596921980381012
# Iteration 73500, loss=0.6977897882461548
# Iteration 73600, loss=0.6728014945983887
# Iteration 73700, loss=0.7293850183486938
# Iteration 73800, loss=0.6952906847000122
# Iteration 168200, loss=0.3956792652606964
# Iteration 168300, loss=0.6714993715286255
# Iteration 168400, loss=0.49382683634757996
# Iteration 168500, loss=0.8407042026519775
# Iteration 168600, loss=0.6479239463806152
# Iteration 168700, loss=0.73041832447052
# Iteration 168800, loss=0.5720187425613403
# Iteration 168900, loss=0.4936271905899048
# Iteration 169000, loss=0.5183382034301758
# Iteration 169100, loss=0.6688323020935059
# Iteration 169200, loss=1.7059968709945679
# Iteration 169300, loss=0.8866296410560608
# Iteration 169400, loss=0.24159368872642517
# Iteration 169500, loss=0.6556109189987183
# Iteration 169600, loss=0.7006679773330688
# Iteration 169700, loss=0.4946575164794922
# Iteration 169800, loss=0.8462310433387756
# Iteration 169900, loss=0.7074119448661804
# Iteration 170000, loss=0.7115864157676697
# Nearest to than: frames, san, reich, ada, buddhism, pin, included, dating,
# Nearest to often: formations, crossed, lessons, geneva, injury, coastline, aftermath, cambodia,
# Nearest to nine: of, zero, the, to, is, and, intel, a,
# Nearest to will: correlation, invoked, place, rely, philosopher, allah, reputation, coca,
# Nearest to used: saxons, longer, sufficiently, imprisoned, programming, sources, kilometers, helpful,
# Nearest to when: that, august, columbia, sketch, substances, vulnerable, importantly, styled,
# Nearest to while: arrive, hughes, runs, diary, referring, funeral, trade, pit,
# Nearest to d: fewer, chamber, cartridges, foster, devil, december, victor, resignation,
# Nearest to called: beavis, impression, intermediate, heaven, mt, sense, romans, concept,
# Nearest to three: whites, possibilities, cemetery, developments, lm, fauna, survive, decisions,
# Nearest to see: pictures, eisenhower, till, minneapolis, innings, prevention, comprises, nutrition,
# Nearest to his: a, one, the, capoeira, spheres, is, and, makes,
# Nearest to be: numerical, sorting, allocated, feature, carol, was, distinguish, defeat,
# Nearest to only: mail, bare, resources, aim, burton, trade, metabolism, dry,
# Nearest to so: prix, able, massachusetts, jimmy, aclu, fever, fc, chaplin,
# Nearest to of: the, and, in, to, a, is, for, as,
# Iteration 170100, loss=0.5120973587036133
# Iteration 170200, loss=0.8816102743148804
# Iteration 170300, loss=0.5168693661689758
# Iteration 170400, loss=0.6295730471611023
# Iteration 170500, loss=0.03452731668949127
# Iteration 170600, loss=0.5866391658782959
# Iteration 170700, loss=0.6082918643951416
# Iteration 170800, loss=0.5736475586891174
# Iteration 170900, loss=0.630675196647644
# Iteration 171000, loss=1.1633810997009277
# Iteration 171100, loss=0.727354884147644
# Iteration 171200, loss=1.1282230615615845
# Iteration 171300, loss=0.5162831544876099
# Iteration 171400, loss=0.5862387418746948
# Iteration 171500, loss=1.0443458557128906
# Iteration 171600, loss=0.5372552871704102
# Iteration 171700, loss=0.9262310266494751
# Iteration 171800, loss=0.611397922039032
# Iteration 171900, loss=0.1899176687002182
# Iteration 172000, loss=0.7853860259056091
# Iteration 172100, loss=0.07225410640239716
# Iteration 172200, loss=0.5696992874145508
# Iteration 172300, loss=0.7620257139205933
# Iteration 172400, loss=0.6035265922546387
# Iteration 172500, loss=0.6075068712234497
# Iteration 172600, loss=0.6997557282447815
# Iteration 180000, loss=0.8139346837997437
# Nearest to than: reich, frames, ada, productive, pin, dating, san, drag,
# Nearest to often: formations, for, in, crossed, injury, lessons, and, as,
# Nearest to nine: of, to, the, is, and, zero, a, in,
# Nearest to will: rely, place, correlation, invoked, course, allah, prc, originated,
# Nearest to used: saxons, longer, sufficiently, lim, correspondence, mainly, foster, inspiration,
# Nearest to when: that, august, by, substances, columbia, milk, beloved, martyr,
# Nearest to while: arrive, hughes, pit, runs, diary, referring, funeral, trade,
# Nearest to d: fewer, cartridges, december, chamber, resignation, jon, foster, roughly,
# Nearest to called: beavis, impression, mt, sense, intermediate, committed, concept, never,
# Nearest to three: whites, developments, possibilities, lm, visited, limestone, cemetery, starred,
# Nearest to see: pictures, eisenhower, innings, comprises, nutrition, minneapolis, till, mel,
# Nearest to his: a, one, the, is, of, to, and, spheres,
# Nearest to be: yeltsin, numerical, feature, allocated, carol, sorting, him, walking,
# Nearest to only: resources, bare, mail, aim, burton, buchanan, almost, trade,
# Nearest to so: prix, fc, instantly, fever, able, jimmy, drivers, ear,
# Nearest to of: the, and, in, a, to, is, for, as,
# Iteration 180100, loss=0.4941072165966034
# Iteration 180200, loss=0.5734436511993408
# Iteration 180300, loss=0.6054198145866394
# Iteration 180400, loss=0.7276648879051208
# Iteration 180500, loss=1.0795345306396484
# Iteration 180600, loss=0.5276868939399719
# Iteration 180700, loss=0.5725501179695129
# Iteration 180800, loss=0.7166711091995239
# Iteration 180900, loss=0.5193243026733398
# Iteration 181000, loss=0.5969451665878296
# Iteration 181100, loss=0.6701448559761047
# Iteration 181200, loss=0.4809935688972473
# Iteration 181300, loss=0.5549318194389343
# Iteration 181400, loss=0.6986569762229919
# Iteration 181500, loss=0.39145514369010925
# Iteration 181600, loss=0.07631747424602509
# Iteration 181700, loss=0.6968989372253418
# Iteration 181800, loss=0.8623270988464355
# Iteration 181900, loss=0.9217301607131958
# Iteration 182000, loss=0.8688359260559082
# Iteration 182100, loss=0.0010612502228468657
# Iteration 182200, loss=0.40417852997779846
# Iteration 182300, loss=0.9119669198989868
# Iteration 182400, loss=0.5069383978843689
# Iteration 182500, loss=0.477453351020813
# Iteration 182600, loss=0.9955763816833496
# Iteration 182700, loss=0.8636151552200317
# Iteration 182800, loss=0.5015425682067871
# Iteration 182900, loss=0.46844470500946045
# Iteration 183000, loss=0.7239694595336914
# Iteration 183100, loss=0.7709967494010925
# Iteration 183200, loss=0.5119990110397339
# Iteration 183300, loss=1.068918228149414
# Iteration 183400, loss=0.8680408596992493
# Iteration 183500, loss=0.7051284909248352
# Iteration 183600, loss=0.7810739278793335
# Iteration 183700, loss=1.826778528793427e-12
# Iteration 183800, loss=0.7238067388534546
# Iteration 183900, loss=0.45043662190437317
# Iteration 184000, loss=0.9613572359085083
# Iteration 184100, loss=0.015461183153092861
# Iteration 184200, loss=0.5846712589263916
# Iteration 184300, loss=0.615048885345459
# Iteration 184400, loss=0.4581865668296814
# Iteration 184500, loss=0.38657426834106445
# Iteration 184600, loss=0.4840331971645355
# Nearest to be: yeltsin, numerical, allocated, distinguish, feature, beaches, carol, joel,

# %%
# Extracting the Embeddings
embedding_layer = model.layers[2]
weights = embedding_layer.get_weights()[0]
print(weights.shape)

# %%
word_index = dictionary
# Saving the weights
import io

out_v = io.open('vecs.tsv', 'w', encoding='utf-8')
out_m = io.open('meta.tsv', 'w', encoding='utf-8')

for word in word_index:
  vec = weights[ int(word_index[word])]
  out_m.write(word + "\n")
  out_v.write('\t'.join([str(x) for x in vec]) + "\n")
out_v.close()
out_m.close()

# %%
# Training on the imdb dataset

import tensorflow_datasets as tfds

# Loading the dataset
(ds_train, ds_test), ds_info = tfds.load(
    'imdb_reviews',
    split=['train', 'test'],
    shuffle_files=True,
    as_supervised=True,
    with_info=True,
)

# %%
x_train, y_train, x_test, y_test = [], [], [], []

for x in ds_train:
  text = str(x[0].numpy()).split("b", 1)[1][1:-1]
  label = x[1].numpy()
  x_train.append(text)
  y_train.append(label)

for x in ds_test:
  text = str(x[0].numpy()).split("b", 1)[1][1:-1]
  label = x[1].numpy()
  x_test.append(text)
  y_test.append(label)

x_train, y_train, x_test, y_test = np.array(x_train), np.array(y_train), np.array(x_test), np.array(y_test)

print(x_train.shape, y_train.shape)

# %%
tokenizer = Tokenizer(num_words = vocab_size)
tokenizer.fit_on_texts(x_train)

# %%
def text2seq(texts, dictionary):
  result = []
  for text in text:
    r = [dictionary[word] for word in text.split() if word in dictionary]
    result.append(r)
  return result

# %%
maxlen = 100
padding = 'post'
truncating = 'post'

sequences = tokenizer.texts_to_sequences(x_train)
sequences = tokenizer.seqeunces_to_texts(sequences)
sequences = text2seq(sequences, dictionary)

seq_train = pad_sequences(sequences, maxlen = maxlen, padding = padding, truncating = truncating)

test_sequences = tokenizer.texts_to_sequences(x_fit)
test_sequences = tokenizer.seqeunces_to_texts(sequences)
test_sequences = text2seq(sequences, dictionary)
seq_test = pad_sequences(test_sequences, maxlen = maxlen, padding = padding, truncating = truncating)

# %%
model = Sequential([
                    Embedding(input_dim = vocab_size+1, output_dim= embedding_dim, input_length = maxlen, weights = weights, trainable = False),
                    LSTM(64, kernel_regularizer=regularizers.l2(0.001), return_sequences=True),
                    Bidirectional(LSTM(64, kernel_regularizer=regularizers.l2(0.001), return_sequences=True)),
                    Bidirectional(LSTM(64, kernel_regularizer=regularizers.l2(0.001))), 
                    Dense(64, activation = 'relu', kernel_regularizer='l2'),
                    Dropout(0.6),
                    Dense(32, activation = 'relu', kernel_regularizer='l2'),
                    Dropout(0.6),
                    Dense(1, activation = 'sigmoid')
])

model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
model.summary()

# %%
history = model.fit(seq_train, y_train, epochs = 50, validation_data = (seq_test, y_test), batch_size = 10000, verbose = 1)

# %%
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
loss=history.history['loss']
val_loss=history.history['val_loss']

epochs=range(len(acc)) 

plt.plot(epochs, acc, 'r')
plt.plot(epochs, val_acc, 'b')
plt.title('Training and validation accuracy')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(["Accuracy", "Validation Accuracy"])
plt.show()

plt.plot(epochs, loss, 'r')
plt.plot(epochs, val_loss, 'b')
plt.title('Training and validation Loss')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(["Loss", "Validation Loss"])
plt.show()
